# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulaLuana/aprendizado-de-maquina/blob/main/Lista4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model as skln

# %% [markdown]
# 1. Implemente uma função Python para cada uma das seguintes métricas de regressão:
#
# * MAE
# * MSE
# * RMSE (Raiz quadrada do MSE)
#
# Cada função deve receber valores reais (y) e valores preditos (y_pred) como parâmetros de entrada e retornar o valor calculado da métrica. Esse parâmetros podem ser arrays do numpy ou DataFrames do Pandas. O ideal é realizar as operações de forma vetorizada, evitando acessar cada célula individualmente. Não usar as implementações já existentes do Scikit-Learn.

# %% [markdown]
# ![mae.png](data:image/png;base64,...)

# %%
def MAE(y, y_pred):
  if type(y) is not np.ndarray:
    y = np.array(y)
  if type(y_pred) is not np.ndarray:
    y_pred = np.array(y_pred)
  return np.average(abs(y - y_pred))

# %% [markdown]
# ![mse.png](data:image/png;base64,...)

# %%
def MSE(y, y_pred):
  if type(y) is not np.ndarray:
    y = np.array(y)
  if type(y_pred) is not np.ndarray:
    y_pred = np.array(y_pred)
  return np.average(pow(abs(y - y_pred),2))

# %% [markdown]
# ![rmse.png](data:image/png;base64,...)

# %%
def RMSE(y, y_pred):
  if type(y) is not np.ndarray:
    y = np.array(y)
  if type(y_pred) is not np.ndarray:
    y_pred = np.array(y_pred)
  return np.sqrt(np.average(pow(abs(y - y_pred),2)))

# %% [markdown]
# 2. Implemente uma função do Python para dividir de forma randomizada o dataset entre treino e teste. A função recebe como parâmetros:
#
# * X - matriz com features
# * y - vetor com rótulos
# * perc_treino - percentual dos dados usados para treino
# * seed - semente de randomização
#
# A função deve retornar: X_train, y_train, X_test, y_test.  Não usar as implementações já existentes do Scikit-Learn.

# %%
def train_test_split(X, y, perc_treino, seed):
  dataset = np.array(list(zip(X,y)))
  np.random.seed(seed)
  np.random.shuffle(dataset)
  n_train = int(round(len(dataset) * perc_treino))
  X_train = dataset[:n_train,:-1]
  y_train = dataset[:n_train,-1]
  X_test = dataset[n_train:,:-1]
  y_test = dataset[n_train:,-1]
  return X_train, y_train, X_test, y_test

# %% [markdown]
# # Análise comparativa
# Faremos uma análise comparativa entre os resultados das funções criadas e das funções do scikit-learn. Para isso, iremos utilizar a regressão linear para os valores das casas.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
dataset = pd

# %%
X = [426.72, 487.68, 518.16, 571.5, 335.28, 472.44, 716.28, 746.76, 434.34, 518.16]
y = [245000, 312000, 279000, 308000, 199000, 219000, 405000, 324000, 319000, 255000]

# %%
X_train, y_train, X_test, y_test = train_test_split(X, y, 0.75, 1)

# %%
regressao = skln.LinearRegression()

# %%
regressao.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressao.predict(X_test)

# %%
resultado = pd.DataFrame([y_test, y_pred], index = ['y_test', 'y_pred'])
resultado
# Out:
#                     0              1
# y_test  319000.000000  219000.000000
# y_pred  250052.617245  264763.385805

# %%
MAE(y_test, y_pred)
# Out:
# 57355.38428018955

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 57355.38428018955

# %%
MSE(y_test, y_pred)
# Out:
# 3424014534.569428

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 3424014534.569428

# %%
RMSE(y_test, y_pred)
# Out:
# 58515.079548518326

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 58515.079548518326
